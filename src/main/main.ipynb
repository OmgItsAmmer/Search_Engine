# %% [markdown]
# Imports

# %%
print("Code is Working")
# Out:
# Code is Working

# %%
import sys
import os

# Add the path to the preprocessing folder to sys.path
preprocessing_folder = os.path.join(os.getcwd(), 'preprocessing')
sys.path.append(preprocessing_folder)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Aleey\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Import the functions from the preprocessing script
# Import the functions from the preprocessing script
import sys
import os

# Add the src/preprocessing folder to the Python path
src_folder = r"E:\Class\3 rd Semester\DSA\Assignments\Project\Search_Engine\src\preprocessing"
sys.path.append(src_folder)

# Import the required functions
from tokenization import tokenize_text_from_csv, lemmatize_tokens


# Define the CSV path
csv_path = r"E:\Class\3 rd Semester\DSA\Assignments\Project\Search_Engine\data\raw_data\fashion-dataset\csv_folder\styles_new.csv"

# Tokenize the text from the CSV file
tokenized_styles = tokenize_text_from_csv(csv_path)

# Lemmatize the tokenized data
lemmatized_data = lemmatize_tokens(tokenized_styles)

# Print the tokenized and lemmatized data
for tokens in lemmatized_data:
    print(tokens)
# Out:
# ['turtle', 'check', 'men', 'navy', 'blue', 'shirt']
# ['peter', 'england', 'men', 'party', 'blue', 'jean']
# ['titan', 'woman', 'silver', 'watch']
# ['manchester', 'united', 'men', 'solid', 'black', 'track', 'pant']
# ['puma', 'men', 'grey']
# ['inkfruit', 'men', 'chain', 'reaction']
# ['fabindia', 'men', 'striped', 'green', 'shirt']
# ['jealous', '21', 'woman', 'purple', 'shirt']
# ['puma', 'men', 'pack', '3', 'sock']
# ['skagen', 'men', 'black', 'watch']
# ['puma', 'men', 'future', 'cat', 'remix', 'sf', 'black', 'casual', 'shoe']
# ['fossil', 'woman', 'black', 'huarache', 'weave', 'belt']
# ['filum', 'men', 'cush', 'flex', 'black', 'slipper']
# ['murcia', 'woman', 'blue', 'handbag']
# ['ben', '10', 'boy', 'navy', 'blue', 'slipper']
# ['reid', 'taylor', 'men', 'check', 'purple', 'shirt']
# ['police', 'men', 'black', 'dial', 'watch', 'pl12889jvsb']
# ['gini', 'jony', 'girl', 'knit', 'white', 'top']
# ['bwitch', 'beige', 'bra', 'bw335']
# ['baggit', 'woman', 'brown', 'handbag']
# ...

# %%
# Build and save the forward index
  # Import the functions from the preprocessing script
# Import the functions from the preprocessing script
import sys
import os

# Add the src/preprocessing folder to the Python path
src_folder = r"E:\Class\3 rd Semester\DSA\Assignments\Project\Search_Engine\index\forward_index"
from forward_index import forward_index, forward_index_path, save_forward_index
forward_index = build_forward_index(lemmatized_data, product_ids)
forward_index_path = r"E:\Class\3 rd Semester\DSA\Assignments\Project\Search_Engine\data\forward_index.json"
save_forward_index(forward_index, forward_index_path)

# %% [markdown]
# Barrel Implementation(New Code)
